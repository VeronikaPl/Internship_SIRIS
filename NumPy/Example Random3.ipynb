# %%
from numpy import random

x = random.exponential(scale=2, size=(2, 3))

print(x)
# Out:
# [[0.35693083 1.33842508 4.00506958]
#  [0.01679781 0.06097546 1.71551731]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.exponential(size=1000), hist=False)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4152\2187777510.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(size=1000), hist=False)

# %%
from numpy import random

x = random.chisquare(df=2, size=(2, 3))

print(x)
# Out:
# [[6.6671641  1.57734878 5.76836732]
#  [0.1106533  0.03657389 4.56805526]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.chisquare(df=1, size=1000), hist=False)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4152\2824890621.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=1, size=1000), hist=False)

# %%
x = random.rayleigh(scale=2, size=(2, 3))

print(x)
# Out:
# [[1.54812337 0.89766486 1.24370903]
#  [2.77822594 2.53511592 1.35458387]]

# %%
sns.distplot(random.rayleigh(size=1000), hist=False)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4152\3971468590.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.rayleigh(size=1000), hist=False)

# %%
x = random.pareto(a=2, size=(2, 3))

print(x)
# Out:
# [[0.27812891 0.51950448 0.39725746]
#  [0.15189812 0.77290739 0.10156621]]

# %%
sns.distplot(random.pareto(a=2, size=1000), kde=False)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4152\2997190916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.pareto(a=2, size=1000), kde=False)

# %%
x = random.zipf(a=2, size=(2, 3))

print(x)
# Out:
# [[2 2 2]
#  [9 1 1]]

# %%
x = random.zipf(a=2, size=1000)
sns.distplot(x[x<10], kde=False)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4152\3948306983.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x[x<10], kde=False)

# %%
import numpy as np
a = np.array([[[1,2,3],[4,5,6]]])

print(a.ndim)
# Out:
# 3

# %%
np.linspace(1,5,5)
# Out:
# array([1., 2., 3., 4., 5.])

# %%
print(np.zeros(5).dtype)
# Out:
# float64

# %%
np.array([[1,2,3],[4,5,6]]).ravel()
# Out:
# array([1, 2, 3, 4, 5, 6])
